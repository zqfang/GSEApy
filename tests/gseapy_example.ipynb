# %% [markdown]
# GSEAPY Example
# -----------------------------------------------
# Examples to use ``GSEApy`` inside python console

# %%
# %matplotlib inline
#%config InlineBackend.figure_format='retina' # mac
import pandas as pd
import gseapy as gp
import matplotlib.pyplot as plt

# %% [markdown]
# **Check gseapy version**

# %%
gp.__version__
# Out:
# '0.9.13'

# %% [markdown]
# ## 1.  Convert IDs Using Biomart API
#
# See validated fiters, attributes, datasets
# ```python
#     >>> from gseapy.parser import Biomart
#     >>> bm = Biomart(verbose=False, host="asia.ensembl.org")
#     >>> ## view validated marts
#     >>> marts = bm.get_marts()
#     >>> ## view validated dataset
#     >>> datasets = bm.get_datasets(mart='ENSEMBL_MART_ENSEMBL')
#     >>> ## view validated attributes
#     >>> attrs = bm.get_attributes(dataset='hsapiens_gene_ensembl')
#     >>> ## view validated filters
#     >>> filters = bm.get_filters(dataset='hsapiens_gene_ensembl')
#     >>> ## query results
#     >>> results = bm.query(dataset='hsapiens_gene_ensembl', attributes=['entrezgene', 'go_id'],
#                           filters={'ensemble_gene_id': [your_input_list]})
# ```

# %%
# read in an example gene list
gene_list = pd.read_csv("./data/gene_list.txt",header=None, sep="\t")
gene_list.head()
# Out:
#                  0
# 0          IGKV4-1
# 1             CD55
# 2             IGKC
# 3          PPFIBP1
# 4            ABHD4

# %%
# convert dataframe or series to list
glist = gene_list.squeeze().str.strip().tolist()
print(glist[:10])
# Out:
# ['IGKV4-1', 'CD55', 'IGKC', 'PPFIBP1', 'ABHD4', 'PCSK6', 'PGD', 'ARHGDIB', 'ITGB2', 'CARD6']

# %%
from gseapy.parser import Biomart

# %%
bm = Biomart()
# Out:
# Creating directory C:\Users\zqfang\AppData\Local\bioservices\bioservices\Cache
# Welcome to Bioservices
# ======================
# It looks like you do not have a configuration file.
# We are creating one with default values in C:\Users\zqfang\AppData\Local\bioservices\bioservices\bioservices.cfg .
# Done

# %%
## BioMart is slow. Be patient
results = bm.query(dataset='hsapiens_gene_ensembl', 
                   attributes=['external_gene_name','entrezgene', 'go_id'],
                   filters={'hgnc_symbol': glist}, filename="query.results.txt")

# %%
# note: pandas read entrez ids as floats, you need to convert them to int 
results.head()
# Out:
#   external_gene_name  entrezgene       go_id
# 0               ABAT        18.0  GO:0003824
# 1               ABAT        18.0  GO:0030170
# 2               ABAT        18.0  GO:0008483
# 3               ABAT        18.0  GO:0003867
# 4               ABAT        18.0  GO:0009448

# %%
results.dtypes
# Out:
# external_gene_name     object
# entrezgene            float64
# go_id                  object
# dtype: object

# %% [markdown]
# ## 2. Enrichr Example

# %% [markdown]
# **See all supported enrichr library names**
#
# Select database from **{ 'Human', 'Mouse', 'Yeast', 'Fly', 'Fish', 'Worm' }**
#
# Enrichr library could be used for ``gsea``, ``ssgsea``, and ``prerank``, too

# %%
names = gp.get_library_name() # default: Human
names[:10]
# Out:
# ['ARCHS4_Cell-lines',
#  'ARCHS4_IDG_Coexp',
#  'ARCHS4_Kinases_Coexp',
#  'ARCHS4_TFs_Coexp',
#  'ARCHS4_Tissues',
#  'Achilles_fitness_decrease',
#  'Achilles_fitness_increase',
#  'Aging_Perturbations_from_GEO_down',
#  'Aging_Perturbations_from_GEO_up',
#  'Allen_Brain_Atlas_down']

# %% [markdown]
# ### 2.1  Assign enrichr with ``pd.Series``,  ``pd.DataFrame``, or ``list`` object

# %% [markdown]
# #### 2.1.1 gene_sets support list, str.
# Multi-libraries names supported, separate each name by comma or input a list.
#
# For example:
# ```python
#     # gene_list
#     gene_list="./data/gene_list.txt",
#     gene_list=glist
#     # gene_sets
#     gene_sets='KEGG_2016'
#     gene_sets='KEGG_2016,KEGG_2013'
#     gene_sets=['KEGG_2016','KEGG_2013']
# ```

# %%
# run enrichr
# if you are only intrested in dataframe that enrichr returned, please set no_plot=True

# list, dataframe, series inputs are supported
enr = gp.enrichr(gene_list="./data/gene_list.txt", 
                 # or gene_list=glist
                 description='test_name', 
                 gene_sets=['KEGG_2016','KEGG_2013'], 
                 outdir='test/enrichr_kegg', 
                 cutoff=0.5 # test dataset, use lower value from range(0,1)
                )

# %%
# access results through res2d attr
# obj.res2d only stores the last enrichr result in your input libraries
# obj.results stores all results
enr.results.head(5)
# Out:
#     Gene_set                                              Term Overlap  \
# 0  KEGG_2016  Osteoclast differentiation_Homo sapiens_hsa04380  28/132
# 1  KEGG_2016                Tuberculosis_Homo sapiens_hsa05152  31/178
# 2  KEGG_2016                   Phagosome_Homo sapiens_hsa04145  28/154
# 3  KEGG_2016               Leishmaniasis_Homo sapiens_hsa05140   17/73
# 4  KEGG_2016        Rheumatoid arthritis_Homo sapiens_hsa05323   19/90
#
#         P-value  Adjusted P-value   Old P-value  Old Adjusted P-value  \
# 0  3.105774e-13      7.888667e-11  9.026468e-10          2.292723e-07
# 1  4.290025e-12      5.448332e-10  7.302987e-09          9.274793e-07
# 2  1.614506e-11      1.366949e-09  1.787601e-08          1.513502e-06
# 3  3.133213e-09      1.591672e-07  6.539155e-07          3.321891e-05
# 4  2.198322e-09      1.395934e-07  5.292880e-07          3.321891e-05
#
#     Z-score  Combined Score                                              Genes
# 0 -1.864151       53.688178  LILRA6;ITGB3;LILRA2;LILRA5;PPP3R1;FCGR3B;SIRPA...
# 1 -1.779908       46.588613  RAB5B;ITGB2;PPP3R1;HLA-DMA;FCGR3B;HLA-DMB;CASP...
# 2 -1.658580       41.214733  ATP6V1A;RAB5B;ITGB5;ITGB3;ITGB2;HLA-DMA;FCGR3B...
# 3 -1.744263       34.154775  TGFB1;IFNGR1;PRKCB;IFNGR2;ITGB2;FOS;MAPK14;HLA...
# 4 -1.688825       33.667700  ATP6V1A;ATP6V1G1;ATP6V0B;TGFB1;ITGB2;FOS;ITGAL...

# %% [markdown]
# #### 2.1.2 Local mode of GO analysis
# If input a .gmt file or gene_set dict object, enrichr runs local.
# **You have to specify the background genes, if local mode used**
#
# For example:
# ```python
#     gene_sets="./data/genes.gmt",
#     gene_sets={'A':['gene1', 'gene2',...],
#                'B':['gene2', 'gene4',...],
#                ...}
# ```

# %%
enr2 = gp.enrichr(gene_list="./data/gene_list.txt", 
                 # or gene_list=glist
                 description='test_name', 
                 gene_sets="./data/genes.gmt",
                 background='hsapiens_gene_ensembl', # or the number of genes, e.g 20000
                 outdir='test/enrichr_kegg2', 
                 cutoff=0.5, # only used for testing.
                 verbose=True)
# Out:
# 2018-12-15 23:57:08,644 User Defined gene sets is given: ./data/genes.gmt
# 2018-12-15 23:57:08,648 Connecting to Enrichr Server to get latest library names
# 2018-12-15 23:57:08,675 using all annotated genes with GO_ID as background genes
# 2018-12-15 23:57:08,698 Background: 19041 hsapiens_gene_ensembl genes with GO_IDs.
# 2018-12-15 23:57:08,702 If this is not you wanted, please give a number to background argument
# 2018-12-15 23:57:08,714 Save file of enrichment results: Job Id:4790634320
# 2018-12-15 23:57:08,965 Done.

# %%
enr2.results.head(5)
# Out:
#            Gene_set        Term Overlap   P-value  Adjusted P-value  \
# 0  CUSTOM4790634320  BvA_UpIN_A   8/139  0.287984          0.581624
# 1  CUSTOM4790634320  BvA_UpIN_B  11/130  0.032532          0.227727
# 2  CUSTOM4790634320  CvA_UpIN_A    1/12  0.424279          0.581624
# 3  CUSTOM4790634320  DvA_UpIN_A  16/284  0.210293          0.581624
# 4  CUSTOM4790634320  DvA_UpIN_D  12/236  0.372799          0.581624
#
#                                                Genes
# 0   MAP3K5;IL1R1;MBOAT2;IQGAP2;MSRB2;HAL;PCSK6;PADI2
# 1  HEBP1;LPAR1;SYK;GPX8;ST3GAL6;DYSF;IL1RAP;ARHGD...
# 2                                             MBOAT2
# 3  MAP3K5;BCL3;PTGS1;IL1R1;ANXA11;FXYD6;ATP6V1B2;...
# 4  SIRPA;HEBP1;LPAR1;TXNDC5;FAM198B;GPX8;ST3GAL6;...

# %% [markdown]
# #### 2.1.3 Plotting

# %%
# simple plotting function
from gseapy.plot import barplot, dotplot
barplot(enr.res2d,title='KEGG_2013',)

# %%
dotplot(enr.res2d, title='KEGG_2013',)

# %% [markdown]
# ### 2.2 Command line usage

# %% [markdown]
# You may also want to use enrichr in command line
#
# the option **-v** will print out the progress of your job

# %%
# !gseapy enrichr -i ./data/gene_list.txt \
#                 --ds BP2017 \
#                 -g GO_Biological_Process_2017 \
#                 -v -o test/enrichr_BP

# %% [markdown]
# ## 3. Prerank example
#
# ### 3.1 Assign prerank()  with a pd.DataFrame, pd.Series , or a txt file
# Do not include header in your gene list !
# GSEApy will skip any data after "#".
# Only contains two columns, or one cloumn with gene_name indexed when assign a ``DataFrame`` to prerank

# %%
rnk = pd.read_csv("./data/edb/gsea_data.gsea_data.rnk", header=None, sep="\t")
rnk.head()
# Out:
#               0         1
# 0        CTLA2B  2.502482
# 1        SCARA3  2.095578
# 2  LOC100044683  1.116398
# 3          CMBL  0.877640
# 4         CLIC6  0.822181

# %%
# run prerank
# enrichr libraries are supported by prerank module. Just provide the name
# use 4 process to acceralate the permutation speed

# note: multiprocessing may not work on windows
pre_res = gp.prerank(rnk=rnk, gene_sets='KEGG_2016', 
                     processes=4,
                     permutation_num=100, # reduce number to speed up testing
                     outdir='test/prerank_report_kegg',format='png')

# %% [markdown]
# Leading edge genes save to the final output results

# %%
#access results through res2d attribute or results
pre_res.res2d.head()
# Out:
#                                                           es       nes  \
# Term
# Pathways in cancer_Homo sapiens_hsa05200           -0.188934 -1.106819
# Cytokine-cytokine receptor interaction_Homo sap...  0.418234  1.509139
# PI3K-Akt signaling pathway_Homo sapiens_hsa04151    0.191372  0.795026
# MAPK signaling pathway_Homo sapiens_hsa04010        0.179667  0.653603
# Rap1 signaling pathway_Homo sapiens_hsa04015        0.221306  0.832700
#
#                                                         pval       fdr  \
# Term
# Pathways in cancer_Homo sapiens_hsa05200            0.225806  0.284722
# Cytokine-cytokine receptor interaction_Homo sap...  0.029851  0.522876
# PI3K-Akt signaling pathway_Homo sapiens_hsa04151    0.662338  0.793651
# MAPK signaling pathway_Homo sapiens_hsa04010        0.800000  0.848039
# Rap1 signaling pathway_Homo sapiens_hsa04015        0.625000  0.875817
#
#                                                     geneset_size  \
# Term
# Pathways in cancer_Homo sapiens_hsa05200                     397
# Cytokine-cytokine receptor interaction_Homo sap...           265
# PI3K-Akt signaling pathway_Homo sapiens_hsa04151             341
# MAPK signaling pathway_Homo sapiens_hsa04010                 255
# Rap1 signaling pathway_Homo sapiens_hsa04015                 211
#
#                                                     matched_size  \
# Term
# Pathways in cancer_Homo sapiens_hsa05200                      27
# Cytokine-cytokine receptor interaction_Homo sap...            18
# PI3K-Akt signaling pathway_Homo sapiens_hsa04151              22
# MAPK signaling pathway_Homo sapiens_hsa04010                  18
# Rap1 signaling pathway_Homo sapiens_hsa04015                  19
#
#                                                                                                 genes  \
# Term
# Pathways in cancer_Homo sapiens_hsa05200            TGFBR2;LAMB3;RET;PDGFRB;ADCY6;ETS1;TGFA;WNT9A;...
# Cytokine-cytokine receptor interaction_Homo sap...  IL13RA1;CSF1;CCL2;TGFBR2;CD40;IL10RB;CXCL10;CX...
# PI3K-Akt signaling pathway_Homo sapiens_hsa04151    CSF1;EFNA1;COL6A1;THBS4;LAMB3;PDGFRB;GNG13;FLT...
# MAPK signaling pathway_Homo sapiens_hsa04010        CACNA1H;TGFBR2;FLNC;MAP3K5;PDGFRB;PPP3CC;NFATC...
# Rap1 signaling pathway_Homo sapiens_hsa04015        CSF1;EFNA1;ARAP3;PDGFRB;ADCY6;PRKD1;MAPK13;FLT...
#
#                                                                                     ledge_genes
# Term
# Pathways in cancer_Homo sapiens_hsa05200                               VEGFC;LPAR4;LEF1;RUNX1T1
# Cytokine-cytokine receptor interaction_Homo sap...  IL13RA1;CSF1;CCL2;TGFBR2;CD40;IL10RB;CXCL10
# PI3K-Akt signaling pathway_Homo sapiens_hsa04151                  CSF1;EFNA1;COL6A1;THBS4;LAMB3
# MAPK signaling pathway_Homo sapiens_hsa04010           CACNA1H;TGFBR2;FLNC;MAP3K5;PDGFRB;PPP3CC
# Rap1 signaling pathway_Homo sapiens_hsa04015                                         CSF1;EFNA1

# %% [markdown]
# ### 3.2 How to generate your GSEA plot inside python console
# Visualize it using ``gseaplot``
#
# Makesure that ``ofname`` is not None, if you want to save your figure

# %%
# extract geneset terms in res2d
terms = pre_res.res2d.index
terms
# Out:
# Index(['Pathways in cancer_Homo sapiens_hsa05200',
#        'Cytokine-cytokine receptor interaction_Homo sapiens_hsa04060',
#        'PI3K-Akt signaling pathway_Homo sapiens_hsa04151',
#        'MAPK signaling pathway_Homo sapiens_hsa04010',
#        'Rap1 signaling pathway_Homo sapiens_hsa04015',
#        'HTLV-I infection_Homo sapiens_hsa05166',
#        'Metabolic pathways_Homo sapiens_hsa01100',
#        'Ras signaling pathway_Homo sapiens_hsa04014',
#        'Focal adhesion_Homo sapiens_hsa04510'],
#       dtype='object', name='Term')

# %%
## easy way
from gseapy.plot import gseaplot

gseaplot(rank_metric=pre_res.ranking, term=terms[0], **pre_res.results[terms[0]])
# to save your figure, makesure that ofname is not None
# gseaplot(rank_metric=pre_res.ranking, term=terms[0], ofname='your.plot.pdf', **pre_res.results[terms[0]])

# %% [markdown]
# ### 3) Command line usage

# %% [markdown]
# You may also want to use prerank in command line

# %%
# ! gseapy prerank -r temp.rnk -g temp.gmt -o prerank_report_temp

# %% [markdown]
# ## 4. GSEA Example
#
# ### 4.1  Assign gsea() with a pandas DataFrame, .gct format file, or a text file
#
# and cls with a list object or just .cls format file

# %%
phenoA, phenoB, class_vector =  gp.parser.gsea_cls_parser("./data/P53.cls")

# %%
#class_vector used to indicate group attributes for each sample
print(class_vector)
# Out:
# ['MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'MUT', 'WT', 'WT', 'WT', 'WT', 'WT', 'WT', 'WT', 'WT', 'WT', 'WT', 'WT', 'WT', 'WT', 'WT', 'WT', 'WT', 'WT']

# %%
gene_exp = pd.read_csv("./data/P53.txt", sep="\t")
gene_exp.head()
# Out:
#         NAME DESCRIPTION   786-0  BT-549  CCRF-CEM  COLO 205    EKVX  \
# 0      TACC2          na   46.05   82.17     16.87     98.60  141.02
# 1  C14orf132          na  108.34   59.04     25.61     33.11   42.53
# 2       AGER          na   42.20   25.75     76.01     40.41   32.17
# 3   32385_at          na    7.43   13.94      8.55     21.13   15.09
# 4      RBM17          na   11.40    3.00      3.16      2.34    4.43
#
#    HCC-2998  HCT-15  HOP-62  ...      MCF7  MOLT-4  NCI-H460  OVCAR-4  SF-539  \
# 0    114.32  134.34   44.95  ...     68.14   32.21    105.89    64.99   53.52
# 1      9.12    9.36  310.96  ...    159.32   10.71     13.59    53.78   57.57
# 2     48.28   58.27   42.40  ...     51.50   61.48     44.44    45.68   54.17
# 3     19.05   16.47    7.60  ...     30.77   21.27     13.36    16.19   12.07
# 4      1.56    6.04    6.16  ...      1.62    2.77      4.42     8.91   12.28
#
#    SK-MEL-5     SR  UACC-257  UACC-62  UO-31
# 0     85.47  18.69     32.16    45.70  48.13
# 1     86.80  17.30    102.66    62.16  73.44
# 2     62.53  83.18     56.57    50.40  36.75
# 3     17.62  22.60      4.50    14.59  11.33
# 4      3.04  10.13      8.32     8.23   3.91
#
# [5 rows x 52 columns]

# %%
print("positively correlated: ", phenoA)
# Out:
# positively correlated:  MUT

# %%
print("negtively correlated: ", phenoB)
# Out:
# negtively correlated:  WT

# %%
# run gsea
# enrichr libraries are supported by gsea module. Just provide the name

gs_res = gp.gsea(data=gene_exp, # or data='./P53_resampling_data.txt'
                 gene_sets='KEGG_2016', # enrichr library names
                 cls= './data/P53.cls', # cls=class_vector
                 #set permutation_type to phenotype if samples >=15
                 permutation_type='phenotype', 
                 permutation_num=100, # reduce number to speed up test
                 outdir=None,  # do not write output to disk
                 no_plot=True, # Skip plotting
                 method='signal_to_noise',
                 processes=4,
                 format='png')

# %%
#access the dataframe results throught res2d attribute
gs_res.res2d.head()
# Out:
#                                                         es       nes  \
# Term
# Type II diabetes mellitus_Homo sapiens_hsa04930  -0.416289 -1.415695
# Autoimmune thyroid disease_Homo sapiens_hsa05320 -0.529900 -1.393443
# Jak-STAT signaling pathway_Homo sapiens_hsa04630 -0.338909 -1.379512
# Circadian entrainment_Homo sapiens_hsa04713      -0.372805 -1.429085
# Morphine addiction_Homo sapiens_hsa05032         -0.369748 -1.356707
#
#                                                       pval       fdr  \
# Term
# Type II diabetes mellitus_Homo sapiens_hsa04930   0.110236  0.553156
# Autoimmune thyroid disease_Homo sapiens_hsa05320  0.090164  0.554575
# Jak-STAT signaling pathway_Homo sapiens_hsa04630  0.061404  0.556689
# Circadian entrainment_Homo sapiens_hsa04713       0.047244  0.560634
# Morphine addiction_Homo sapiens_hsa05032          0.116279  0.564603
#
#                                                   geneset_size  matched_size  \
# Term
# Type II diabetes mellitus_Homo sapiens_hsa04930             48            38
# Autoimmune thyroid disease_Homo sapiens_hsa05320            53            39
# Jak-STAT signaling pathway_Homo sapiens_hsa04630           158           125
# Circadian entrainment_Homo sapiens_hsa04713                 95            75
# Morphine addiction_Homo sapiens_hsa05032                    91            71
#
#                                                                                               genes  \
# Term
# Type II diabetes mellitus_Homo sapiens_hsa04930   PIK3CA;HK2;MAPK9;MAPK1;MAPK8;IRS1;IRS4;SLC2A4;...
# Autoimmune thyroid disease_Homo sapiens_hsa05320  HLA-DOB;CGA;CD86;TSHB;IFNA2;TSHR;HLA-DRB4;HLA-...
# Jak-STAT signaling pathway_Homo sapiens_hsa04630  PIK3CA;EP300;SOCS5;OSMR;IL6ST;IL7R;FHL1;GFAP;I...
# Circadian entrainment_Homo sapiens_hsa04713       GNB1;GNG5;GNAI3;CALM2;CAMK2G;GNG10;GRIA2;PLCB3...
# Morphine addiction_Homo sapiens_hsa05032          GNB1;GNG5;GNAI3;PDE1C;GNG10;GABRP;GNAI2;GRK4;G...
#
#                                                                                         ledge_genes
# Term
# Type II diabetes mellitus_Homo sapiens_hsa04930   PRKCD;CACNA1D;IKBKB;CACNA1E;PIK3CG;SLC2A2;INS;...
# Autoimmune thyroid disease_Homo sapiens_hsa05320  HLA-DRA;HLA-DMA;IFNA5;HLA-DPA1;IL2;HLA-DQB1;HL...
# Jak-STAT signaling pathway_Homo sapiens_hsa04630  STAT5A;GHR;IL10;AKT1;IFNW1;LIF;PIAS1;CTF1;PIAS...
# Circadian entrainment_Homo sapiens_hsa04713       CACNA1D;ADCY9;GNGT1;ADCY7;GNG7;PLCB4;RYR3;PLCB...
# Morphine addiction_Homo sapiens_hsa05032          ADCY3;GABRR1;PDE4A;GABRB1;PDE3B;ADCY9;GABRA1;A...

# %% [markdown]
# ### 4.2 Show the gsea plots
#
# The **gsea** module will generate heatmap for genes in each gene sets in the backgroud.
# But if you need to do it yourself, use the code below

# %%
from gseapy.plot import gseaplot, heatmap
terms = gs_res.res2d.index
# Makesure that ``ofname`` is not None, if you want to save your figure to disk
gseaplot(gs_res.ranking, term=terms[0], **gs_res.results[terms[0]])

# %%
# plotting heatmap
genes = gs_res.res2d.genes[0].split(";")
# Makesure that ``ofname`` is not None, if you want to save your figure to disk
heatmap(df = gs_res.heatmat.loc[genes], z_score=0, title=terms[0], figsize=(18,6))

# %% [markdown]
# ### 4.3 Command line usage

# %% [markdown]
# You may also want to use gsea in command line

# %%
# !gseapy gsea -d ./data/P53_resampling_data.txt \
#              -g KEGG_2016 -c ./data/P53.cls \
#              -o test/gsea_reprot_2 \
#              -v --no-plot \
#              -t phenotype

# %% [markdown]
# ## 5. Single Sample GSEA example
#
# **Note: When you run ssGSEA, all genes names in your gene_sets file should be found in your expression table**
#
# ### 5.1 Input format
# Assign ssgsea() with a txt file, gct file, pd.DataFrame, or pd.Seires(gene name as index)

# %%
# txt, gct file input
ss = gp.ssgsea(data="./data/testSet_rand1200.gct",
               gene_sets="./data/randomSets.gmt", 
               outdir='test/ssgsea_report', 
               sample_norm_method='rank', # choose 'custom' for your own rank list
               permutation_num=0, # skip permutation procedure, because you don't need it
               no_plot=True, # skip plotting, because you don't need these figures
               processes=4, format='png')

# %%
ss.res2d
# Out:
#                 AA488_A1.2  AA489_A2.2  AA490_A3  AA491_B1  AA492_B2  \
# Term|NES
# level10_RAND      0.409675    0.412178  0.402321  0.420735  0.423723
# level12_random    0.623442    0.637662  0.624727  0.636428  0.644896
# level2_rand      -0.271914   -0.281744 -0.271358 -0.277807 -0.279207
# level4_rand      -0.061550   -0.090115 -0.063876 -0.094134 -0.094397
# level6_rand      -0.061075   -0.054566 -0.061283 -0.052871 -0.054915
# level8_rand       0.145081    0.157404  0.165249  0.160468  0.141703
# random1           0.154009    0.151312  0.151478  0.147901  0.151960
# random2           0.114789    0.111621  0.101720  0.112612  0.113221
# random3           0.090674    0.103528  0.101386  0.099922  0.101013
# random4           0.085871    0.080253  0.092358  0.074533  0.071283
# random5           0.063539    0.063641  0.057671  0.064427  0.063732
#
#                 AA493_B3  AA494_C1.2  AA495_C2  AA496_C3  AA497_D1.2  \
# Term|NES
# level10_RAND    0.399593    0.417449  0.426562  0.414945    0.427697
# level12_random  0.628848    0.645327  0.633330  0.637862    0.647586
# level2_rand    -0.260003   -0.294843 -0.289941 -0.286516   -0.294068
# level4_rand    -0.053017   -0.096070 -0.081046 -0.080501   -0.092273
# level6_rand    -0.047231   -0.059001 -0.069959 -0.061611   -0.055635
# level8_rand     0.172145    0.139912  0.173172  0.153195    0.146414
# random1         0.140935    0.154359  0.157054  0.152341    0.150122
# random2         0.106218    0.120733  0.131228  0.113305    0.125728
# random3         0.098896    0.095853  0.080370  0.100862    0.089775
# random4         0.079997    0.077435  0.065426  0.081537    0.063962
# random5         0.047877    0.068045  0.080220  0.060985    0.072431
#
#                 AA498_D3.2  AA499_D2  AA500_x2  AA501_X3  AA502_X2.2  \
# Term|NES
# level10_RAND      0.428861  0.439795  0.439169  0.429886    0.421071
# level12_random    0.648293  0.638572  0.652058  0.650088    0.653153
# level2_rand      -0.285716 -0.286194 -0.335032 -0.331248   -0.337686
# level4_rand      -0.092036 -0.078247 -0.119548 -0.120003   -0.129959
# level6_rand      -0.058775 -0.062907 -0.020677 -0.017325   -0.011440
# level8_rand       0.127259  0.165137  0.175863  0.166732    0.175394
# random1           0.147418  0.157688  0.125304  0.117738    0.109891
# random2           0.118026  0.139158  0.090622  0.084933    0.083598
# random3           0.098816  0.088680  0.098413  0.107809    0.099561
# random4           0.066237  0.062175  0.063953  0.061089    0.055425
# random5           0.061967  0.075577  0.107136  0.094497    0.099291
#
#                 AA503_Y1  AA504_Y2  AA505_Y3
# Term|NES
# level10_RAND    0.433796  0.436511  0.427593
# level12_random  0.660680  0.659886  0.648956
# level2_rand    -0.336926 -0.334273 -0.339320
# level4_rand    -0.143212 -0.138202 -0.126784
# level6_rand    -0.018986 -0.017288 -0.009031
# level8_rand     0.166237  0.169276  0.192095
# random1         0.113501  0.115591  0.110315
# random2         0.080412  0.087921  0.100607
# random3         0.103815  0.105186  0.098073
# random4         0.052380  0.053036  0.069909
# random5         0.096348  0.100260  0.098746

# %%
from gseapy.plot import heatmap
heatmap(ss.res2d)

# %%
# or assign a dataframe, or Series to ssgsea()
ssdf = pd.read_csv("./data/temp.txt", header=None, sep="\t")
ssdf.head()
# Out:
#         0          1
# 0   ATXN1  16.456753
# 1  UBQLN4  13.989493
# 2   CALM1  13.745533
# 3    DLG4  12.796588
# 4  MRE11A  12.787631

# %%
# dataframe with one column is also supported by ssGSEA or Prerank
# But you have to set gene_names as index
ssdf2 = ssdf.set_index(0)
ssdf2.head()
# Out:
#                 1
# 0
# ATXN1   16.456753
# UBQLN4  13.989493
# CALM1   13.745533
# DLG4    12.796588
# MRE11A  12.787631

# %%
type(ssdf2)
# Out:
# pandas.core.frame.DataFrame

# %%
ssSeries = ssdf2.squeeze()
type(ssSeries)
# Out:
# pandas.core.series.Series

# %%
# reuse data
df = pd.read_csv("./data/P53_resampling_data.txt", sep="\t")
df.head()
# Out:
#            NAME   786-0  BT-549  CCRF-CEM  COLO 205    EKVX  HCC-2998  HCT-15  \
# 0        CTLA2B  111.19   86.22    121.85     75.19  208.62    130.59  124.72
# 1        SCARA3  460.30  558.34    183.55     37.29  158.00     43.61   80.83
# 2  LOC100044683   97.25  118.94     81.17    119.51  119.88    107.73  165.57
# 3          CMBL   33.45   55.10    221.67     50.30   35.12     75.70   84.01
# 4         CLIC6   35.75   41.26     63.04    219.86   42.53     54.19   86.98
#
#    HOP-62   HOP-92   ...      MCF7  MOLT-4  NCI-H460  OVCAR-4  SF-539  \
# 0  324.09   242.71   ...    163.76   59.50    134.12   152.09  197.46
# 1  300.08  1250.25   ...    109.91  120.42     73.06   115.03   95.12
# 2  203.97   135.43   ...    222.84  124.98    114.75   141.66  170.19
# 3   44.12    79.96   ...     51.32  117.11     59.46    78.46   45.55
# 4   71.20    53.89   ...    154.05   31.62     37.66    32.64   63.35
#
#    SK-MEL-5      SR  UACC-257  UACC-62   UO-31
# 0    137.79   81.53    123.37    81.41  180.78
# 1     37.56   76.16     41.10    77.51  519.17
# 2    147.70  157.48    152.18    98.89  118.06
# 3     49.07   96.69     33.09    10.38   52.89
# 4     27.95   70.99     36.25    17.50   49.41
#
# [5 rows x 51 columns]

# %%
# Series, DataFrame Example
# supports dataframe and series
ssgs = []
for i, dat in enumerate([ssdf, ssdf2, ssSeries, df]):
    sstemp = gp.ssgsea(data=dat, 
                       gene_sets="./data/genes.gmt", 
                       outdir='test/ssgsea_report_'+str(i),
                       scale=False, # set scale to False to get real original ES
                       permutation_num=0, # skip permutation procedure, because you don't need it
                       no_plot=True, # skip plotting, because you don't need these figures
                       processes=4, 
                       format='png')
    ssgs.append(sstemp)
# Out:
# 2018-12-15 23:58:05,908 Warning: dropping duplicated gene names, only keep the first values

# %% [markdown]
# ### 5.2 Access Enrichment Score (ES) and NES
#
# results save to two attribute:
#
# 1. obj.resultsOnSamples: ES
# 2. obj.res2d: NES

# %%
# normalized es save to res2d attri
# one sample input
# NES
ssgs[0].res2d.head()
# Out:
#                    1
# Term|NES
# BvA_UpIN_A  2.150114
# BvA_UpIN_B  2.953848
# DvA_UpIN_A  1.985451
# DvA_UpIN_D  2.457489
# YvX_UpIN_X  2.148816

# %% [markdown]
# **Note**:
# If you want to obtain the real original enrichment score,
# you have to set ``scale=False``

# %%
# ES
# convert dict to DataFrame
es = pd.DataFrame(ssgs[-1].resultsOnSamples)
es.head()
# Out:
#                 786-0     BT-549   CCRF-CEM   COLO 205       EKVX   HCC-2998  \
# Term|ES
# DvA_UpIN_A  45.703475   6.724266  11.881146  20.639710  36.753558   3.530987
# DvA_UpIN_D  82.960021  86.151980  88.176462  65.077923  80.856467  63.085467
#
#                HCT-15     HOP-62     HOP-92    HS 578T    ...           MCF7  \
# Term|ES                                                   ...
# DvA_UpIN_A   5.257504  33.003838  29.227462  41.404387    ...       4.304996
# DvA_UpIN_D  53.584047  73.531016  85.803567  87.688120    ...      72.525357
#
#                MOLT-4   NCI-H460    OVCAR-4     SF-539   SK-MEL-5         SR  \
# Term|ES
# DvA_UpIN_A  17.789549  19.172561  37.144472  40.135942  18.082717  13.901976
# DvA_UpIN_D  85.020685  76.225849  90.948093  97.684104  62.334470  68.252995
#
#              UACC-257    UACC-62      UO-31
# Term|ES
# DvA_UpIN_A  44.562272  52.021549  51.156682
# DvA_UpIN_D  73.484066  68.122566  86.657296
#
# [2 rows x 50 columns]

# %%
# if set scale to True, then 
# Scaled ES equal to es/gene_numbers
ses = es/df.shape[0]
ses
# Out:
#                786-0    BT-549  CCRF-CEM  COLO 205      EKVX  HCC-2998  \
# Term|ES
# DvA_UpIN_A  0.065855  0.009689  0.017120  0.029740  0.052959  0.005088
# DvA_UpIN_D  0.119539  0.124138  0.127055  0.093772  0.116508  0.090901
#
#               HCT-15    HOP-62    HOP-92   HS 578T    ...         MCF7  \
# Term|ES                                               ...
# DvA_UpIN_A  0.007576  0.047556  0.042114  0.059660    ...     0.006203
# DvA_UpIN_D  0.077210  0.105952  0.123636  0.126352    ...     0.104503
#
#               MOLT-4  NCI-H460   OVCAR-4    SF-539  SK-MEL-5        SR  \
# Term|ES
# DvA_UpIN_A  0.025633  0.027626  0.053522  0.057833  0.026056  0.020032
# DvA_UpIN_D  0.122508  0.109836  0.131049  0.140755  0.089819  0.098347
#
#             UACC-257   UACC-62     UO-31
# Term|ES
# DvA_UpIN_A  0.064211  0.074959  0.073713
# DvA_UpIN_D  0.105885  0.098159  0.124866
#
# [2 rows x 50 columns]

# %%
# NES 
# scale or no have no affects on final nes value
nes = ssgs[-1].res2d
nes.head()
# Out:
#                786-0    BT-549  CCRF-CEM  COLO 205      EKVX  HCC-2998  \
# Term|NES
# DvA_UpIN_A  0.402250  0.059182  0.104570  0.181656  0.323479  0.031077
# DvA_UpIN_D  0.730157  0.758250  0.776068  0.572771  0.711643  0.555235
#
#               HCT-15    HOP-62    HOP-92   HS 578T    ...         MCF7  \
# Term|NES                                              ...
# DvA_UpIN_A  0.046273  0.290477  0.257240  0.364413    ...     0.037890
# DvA_UpIN_D  0.471610  0.647169  0.755184  0.771770    ...     0.638318
#
#               MOLT-4  NCI-H460   OVCAR-4    SF-539  SK-MEL-5        SR  \
# Term|NES
# DvA_UpIN_A  0.156571  0.168744  0.326920  0.353249  0.159152  0.122356
# DvA_UpIN_D  0.748293  0.670887  0.800462  0.859748  0.548625  0.600716
#
#             UACC-257   UACC-62     UO-31
# Term|NES
# DvA_UpIN_A  0.392206  0.457858  0.450246
# DvA_UpIN_D  0.646756  0.599568  0.762698
#
# [2 rows x 50 columns]

# %% [markdown]
# ### 3) command line usage of single sample gsea

# %%
# set --no-scale to obtain the real original enrichment score
# !gseapy ssgsea -d ./data/testSet_rand1200.gct \
#                -g data/temp.gmt \
#                -o test/ssgsea_report2  \
#                -p 4 --no-plot --no-scale

# %% [markdown]
# ## 6. Replot Example
#
# ### 6.1 locate your directory
#
# notes: ``replot`` module need to find edb folder to work properly.
# keep the file tree like this:
# ```
# data
#  |--- edb
#  |    |--- C1OE.cls
#  |    |--- gene_sets.gmt
#  |    |--- gsea_data.gsea_data.rnk
#  |    |--- results.edb
#
# ```

# %%
# run command inside python console
rep = gp.replot(indir="./data", outdir="test/replot_test")

# %% [markdown]
# ### 6.2 command line usage of replot

# %%
# !gseapy replot -i data -o test/replot_test
